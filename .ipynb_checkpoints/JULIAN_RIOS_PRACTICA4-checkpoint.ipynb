# %% [markdown]
# Descripción de la actividad:
#
# Durante esta actividad, nos centraremos en la resolución de ejercicios prácticos de contraste de hipótesis, regresión lineal y regresión logística. Todos los ejercicios a continuación deben desarrollarse a partir de las conclusiones desarrolladas del análisis exploratorio de datos realizados en la etapa anterior.
#
# Considerando su conjunto de datos y la cuestión de investigación definidas en el taller anterior. Plantee la hipótesis nula y alternativa. La hipótesis nula (H0) debe representar la afirmación inicial que presupone la ausencia de un efecto o relación significativa en la población. Por otro lado, la hipótesis alternativa (H1) debe desafiar esta suposición al afirmar la existencia de un efecto o relación. Es crucial que ambas hipótesis sean verificables a través de métodos estadísticos.
# Asegúrese de que las hipótesis nula y alternativa sean mutuamente excluyentes, lo que significa que no deben superponerse en términos de afirmaciones. Además, deben ser colectivamente exhaustivas, lo que implica que juntas deben cubrir todas las posibles situaciones en el contexto de su investigación. Esta condición es esencial para garantizar que el contraste de hipótesis sea completo y adecuado.
# Seleccione una prueba estadística teniendo en cuenta los datos. La elección de la prueba estadística es crucial y debe basarse en la naturaleza de sus datos y las hipótesis formuladas. Por ejemplo, si está comparando medias de dos grupos, una prueba t podría ser apropiada. Si está analizando la asociación entre variables categóricas, una prueba chi-cuadrado podría ser la mejor opción. Justifique su elección explicando por qué la prueba seleccionada es la más adecuada para abordar su pregunta de investigación. Por ejemplo, si está utilizando una prueba t, explique que esta prueba es adecuada para comparar medias entre dos grupos independientes.
# Utilice la biblioteca scipy.stats para llevar a cabo el contraste de hipótesis. Proporcione código que ejecute la prueba y justifique los parámetros utilizados. Por ejemplo, si está realizando una prueba t de dos muestras, incluya el código que cargue los datos, calcule la estadística de prueba y el p-valor, y explique la interpretación de estos resultados. Asegúrese de detallar cualquier configuración específica de la prueba, como la elección de prueba bilateral o unilateral.
# Después de realizar la prueba, interprete los resultados en el contexto de su investigación. Evalúe si puede rechazar la hipótesis nula o no, en función del nivel de significancia (alfa) que haya elegido (por ejemplo, alfa = 0.05). Reporte los valores obtenidos, como la estadística de prueba y el p-valor. Explique qué significan estos valores y cómo impactan en la evaluación de sus hipótesis. Por ejemplo, si el p-valor es menor que alfa, indique que tiene evidencia suficiente para rechazar la hipótesis nula.
# Redacte una conclusión basada en los resultados del contraste de hipótesis. Explique qué indican los hallazgos sobre los datos y cómo responden a la pregunta de investigación inicial. Por ejemplo, si rechaza la hipótesis nula, indique que hay evidencia estadística de que existe una relación significativa entre las variables en estudio. Asegúrese de ser claro y específico en su interpretación, y vincule los resultados de la prueba con el contexto de su investigación.
# Regresión lineal
#
# En la actividad anterior se realizó una regresión simple, para esta actividad debe seleccionar al menos tres variables continuas independientes (características) y una variable dependiente (variable objetivo) que deseen predecir.
#
# Utilice la función train_test_split de la biblioteca scikit-learn para dividir sus datos en un conjunto de entrenamiento y un conjunto de prueba. Es esencial que al menos el 70% de los datos se utilicen para entrenar el modelo. Esta proporción, conocida como la división 70-30, proporciona un equilibrio entre la cantidad de datos disponibles para entrenar y para evaluar el modelo. Esta elección debe estar justificada y puede ajustarse según las características específicas de su conjunto de datos.
# Emplee la clase LinearRegression de scikit-learn para instanciar un modelo de regresión lineal multidimensional. Este modelo permitirá explorar y modelar las relaciones entre múltiples características de sus datos.
# Utilice el método fit del modelo para llevar a cabo el ajuste a los datos de entrenamiento. Este paso es fundamental ya que el modelo aprenderá a representar la relación entre las características y la variable dependiente a partir de estos datos.
# Utilice el atributo coef_ del modelo para obtener los coeficientes de regresión asociados a cada característica. Estos coeficientes representan la contribución de cada característica en la predicción de la variable dependiente. Es crucial analizar si los resultados obtenidos concuerdan con las expectativas previas. Si hay discrepancias, es posible que algunas características tengan un impacto inesperado o que se necesite un ajuste adicional del modelo.
# Utilice el atributo intercept_ del modelo para obtener el término de intercepción. Este término representa el valor esperado de la variable dependiente cuando todas las características son iguales a cero. Es una parte importante de la ecuación de regresión y puede influir significativamente en las predicciones del modelo.
# Utilice el conjunto de prueba que ha separado previamente para realizar predicciones utilizando el modelo ajustado. Utilice el método predict para obtener las predicciones del modelo sobre este conjunto de datos independiente.
# Calcule el Error Cuadrático Medio (MSE), que es una medida de la calidad de las predicciones del modelo. Representa el promedio de los cuadrados de las diferencias entre las predicciones y los valores reales. Un MSE más bajo indica que las predicciones del modelo están más cerca de los valores reales, lo que sugiere un modelo más preciso.
# Calcule el coeficiente de determinación (R²), que proporciona una medida de la proporción de la varianza en la variable dependiente que es predecible a partir de las características. Un R² cercano a 1 indica un buen ajuste del modelo a los datos.
# Considerando la problemática inicial y los resultados obtenidos, analice si la regresión lineal ha proporcionado información adicional sobre los datos. Evalúe si el modelo ha logrado capturar las relaciones entre las características y la variable dependiente de manera significativa y si ha proporcionado conocimientos nuevos.
# Indique cuál sería la siguiente prueba a realizar y explique la razón detrás de esta elección. Mencione los resultados esperados y cómo estos podrían contribuir a una comprensión más profunda del problema o a la mejora del modelo.
# Regresión logística
#
# Partiendo de la base datos con la que se ha estado trabajando, selecciona dos variables, una variable continua y otra variable categórica o binaria. Si no se tienen datos cate puede crear dos categorías utilizando algún umbral (solo para los propósitos del ejercicio, siempre que se tenga información continua se debe aprovechar).
#
# Divida los datos en un conjunto de entrenamiento y un conjunto de prueba utilizando la función train_test_split de scikit-learn. Asegúrese de que al menos el 70% de los datos se utilicen para entrenar el modelo, como es común en problemas de clasificación.
# Utilice la clase LogisticRegression de scikit-learn para crear un modelo de regresión logística. Recuerde que la regresión logística es ideal para problemas de clasificación binaria.
# Ajuste el modelo a los datos de entrenamiento utilizando el método fit. Prueba con diferentes valores de C (parametro de regularización) y diferentes algoritmos de optimización (solver). Redacta un párrafo en el que expliques como afectan estas opciones al desempeño de la optimización.
# Obtenga los coeficientes de regresión para cada característica utilizando el atributo coef. ¿Cuál es la diferencia en cómo se utilizan estos coeficientes para realizar predicciones respecto o a los obtenidos mediante una regresión lineal?
# Obtenga el término de intercepción utilizando el atributo intercept_. Esto representa la probabilidad de pertenecer a la clase positiva cuando todas las características son iguales a cero.
# Utilizando el conjunto de prueba, realiza predicciones utilizando el modelo ajustado con el método predict. Asegúrate de que las predicciones estén en el rango [0, 1] y establece un umbral adecuado para clasificarlas en las clases, justifique su elección.
# Por ejemplo, en un examen para detectar cáncer se puede tener una menor tolerancia al error que seleccionar un producto en un sistema de recomendación.
# Calcula la precisión del modelo en el conjunto de prueba. La precisión es importante, pero también considera otras métricas como la sensibilidad y la especificidad para obtener una imagen completa del rendimiento del modelo.
# Calcula la matriz de confusión del modelo en el conjunto de prueba. La matriz de confusión proporciona información detallada sobre los aciertos y los errores de clasificación.
#
#
# Entregable:
#
# Presentar un reporte en pdf de manera individual en el que se evidencie el desarrollo de las actividades propuestas, se deben incluir todos los soportes para respaldar las conclusiones: imágenes, fragmentos de código, resultados de consola, etc. Todos los recursos externos empleados deben ser referenciados apropiadamente.
# Puede utilizar Quarto para producir reportes que incluyen automáticamente los resultados de la ejecución de código.

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder

# %%
def query_data_paginated(url, params={}, headers={}, page_size=1000):
    """
    Queries data from the specified URL using paginated requests with offset and limit parameters.

    Args:
        url (str): The URL of the API endpoint.
        params (dict, optional): Additional query parameters to include. Defaults to {}.
        headers (dict, optional): HTTP headers to include in the request. Defaults to {}.
        page_size (int, optional): The number of records to retrieve per page. Defaults to 1000.

    Returns:
        list: A list of all retrieved data records.
    """

    all_data = []
    offset = 0

    while True:
        limit = page_size
        params["$offset"] = offset
        params["$limit"] = limit

        try:
            response = requests.get(url, headers=headers, params=params)
            response.raise_for_status()  # Raise an exception if request fails
        except requests.exceptions.RequestException as e:
            print(f"Error making request: {e}")
            break

        data = response.json() 

        if not data:  
            break

        all_data.extend(data)
        offset += limit

    return all_data

url = "https://www.datos.gov.co/resource/qhpu-8ixx.json"
headers = {"Accept": "application/json"} 

data = query_data_paginated(url, headers=headers)
df = pd.DataFrame(data)

print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 43
#      40 url = "https://www.datos.gov.co/resource/qhpu-8ixx.json"
#      41 headers = {"Accept": "application/json"}
# ---> 43 data = query_data_paginated(url, headers=headers)
#      44 df = pd.DataFrame(data)
#      46 print(df)
#
# Cell In[6], line 24, in query_data_paginated(url, params, headers, page_size)
#      21 params["$limit"] = limit
#      23 try:
# ---> 24     response = requests.get(url, headers=headers, params=params)
#      25     response.raise_for_status()  # Raise an exception if request fails
#      26 except requests.exceptions.RequestException as e:
#
# File D:\anaconda\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File D:\anaconda\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File D:\anaconda\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File D:\anaconda\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File D:\anaconda\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File D:\anaconda\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File D:\anaconda\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File D:\anaconda\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File D:\anaconda\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File D:\anaconda\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File D:\anaconda\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File D:\anaconda\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File D:\anaconda\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File D:\anaconda\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
import pandas as pd

# Realiza la solicitud a la API
url = "https://www.datos.gov.co/resource/qhpu-8ixx.json"
respuesta = requests.get(url)

# Si la solicitud es exitosa, convierte la respuesta a JSON
if respuesta.status_code == 200:
    datos = respuesta.json()

    # Crea un DataFrame a partir de los datos JSON
    df = pd.DataFrame(datos)

    # Muestra el DataFrame
    print(df.to_string())

else:
    print("Error al realizar la solicitud a la API")
#  25  rentabilidad_anual            1000 non-null   object
# dtypes: object(26)
# memory usage: 203.3+ KB

# %% [markdown]
# ## Corrección de campos

# %%
# Diccionario con los tipos de datos
tipos_datos = {
"fecha_corte":"datetime64[ns]",
"tipo_entidad":"int64",         
"nombre_tipo_entidad":"str",
"codigo_entidad":"int64",	   
"nombre_entidad":"str",       
"tipo_negocio":"int64",         
"nombre_tipo_patrimonio":"str",
"subtipo_negocio":"int64",      
"nombre_subtipo_patrimonio":"str",
"codigo_negocio":"int64",      
"nombre_patrimonio":"str",  
"principal_compartimento":"int64",
"tipo_participacion":"int64",   
"rendimientos_abonados":"int64",
"precierre_fondo_dia_t":"int64",
"numero_unidades_fondo_cierre":"int64", 
"valor_unidad_operaciones":"int64",
"aportes_recibidos":"int64",
"retiros_redenciones":"int64",  
"anulaciones":"int64",      
"valor_fondo_cierre_dia_t":"int64",
"numero_inversionistas":"int64", 
"rentabilidad_diaria":"int64", 
"rentabilidad_mensual":"int64", 
"rentabilidad_semestral":"int64",
"rentabilidad_anual":"int64"
}

# Cambia el tipo de dato de las columnas
for campo, tipo in tipos_datos.items():
    df[campo] = df[campo].astype(tipo)

# %%
df.to_csv('datos.csv', index=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   fecha_corte                   1000 non-null   datetime64[ns]
#  1   tipo_entidad                  1000 non-null   int64
#  2   nombre_tipo_entidad           1000 non-null   object
#  3   codigo_entidad                1000 non-null   int64
#  4   nombre_entidad                1000 non-null   object
#  5   tipo_negocio                  1000 non-null   int64
#  6   nombre_tipo_patrimonio        1000 non-null   object
#  7   subtipo_negocio               1000 non-null   int64
#  8   nombre_subtipo_patrimonio     1000 non-null   object
#  9   codigo_negocio                1000 non-null   int64
#  10  nombre_patrimonio             1000 non-null   object
#  11  principal_compartimento       1000 non-null   int64
#  12  tipo_participacion            1000 non-null   int64
#  13  rendimientos_abonados         1000 non-null   int64
#  14  precierre_fondo_dia_t         1000 non-null   int64
#  15  numero_unidades_fondo_cierre  1000 non-null   int64
#  16  valor_unidad_operaciones      1000 non-null   int64
#  17  aportes_recibidos             1000 non-null   int64
#  18  retiros_redenciones           1000 non-null   int64
#  19  anulaciones                   1000 non-null   int64
#  20  valor_fondo_cierre_dia_t      1000 non-null   int64
#  21  numero_inversionistas         1000 non-null   int64
#  22  rentabilidad_diaria           1000 non-null   int64
#  23  rentabilidad_mensual          1000 non-null   int64
#  24  rentabilidad_semestral        1000 non-null   int64
#  25  rentabilidad_anual            1000 non-null   int64
# dtypes: datetime64[ns](1), int64(20), object(5)
# memory usage: 203.3+ KB

# %% [markdown]
# # Limpieza inicial

# %%
df.isnull().sum()
# Out:
# fecha_corte                     0
# tipo_entidad                    0
# nombre_tipo_entidad             0
# codigo_entidad                  0
# nombre_entidad                  0
# tipo_negocio                    0
# nombre_tipo_patrimonio          0
# subtipo_negocio                 0
# nombre_subtipo_patrimonio       0
# codigo_negocio                  0
# nombre_patrimonio               0
# principal_compartimento         0
# tipo_participacion              0
# rendimientos_abonados           0
# precierre_fondo_dia_t           0
# numero_unidades_fondo_cierre    0
# valor_unidad_operaciones        0
# aportes_recibidos               0
# retiros_redenciones             0
# anulaciones                     0
# valor_fondo_cierre_dia_t        0
# numero_inversionistas           0
# rentabilidad_diaria             0
# rentabilidad_mensual            0
# rentabilidad_semestral          0
# rentabilidad_anual              0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                                count                        mean  \
# fecha_corte                     1000  2024-03-13 20:49:55.200000
# tipo_entidad                  1000.0                       24.12
# codigo_entidad                1000.0                      22.621
# tipo_negocio                  1000.0                         9.0
# subtipo_negocio               1000.0                       2.675
# codigo_negocio                1000.0                   65375.838
# principal_compartimento       1000.0                        1.19
# tipo_participacion            1000.0                      602.91
# rendimientos_abonados         1000.0                31000751.902
# precierre_fondo_dia_t         1000.0         156850687236.975006
# numero_unidades_fondo_cierre  1000.0         742320246415.905029
# valor_unidad_operaciones      1000.0                  142603.627
# aportes_recibidos             1000.0              5273868788.563
# retiros_redenciones           1000.0              6595775782.823
# anulaciones                   1000.0               -25781589.946
# valor_fondo_cierre_dia_t      1000.0          155502998652.69101
# numero_inversionistas         1000.0                    1554.998
# rentabilidad_diaria           1000.0                   82630.327
# rentabilidad_mensual          1000.0                       14.46
# rentabilidad_semestral        1000.0                      44.331
# rentabilidad_anual            1000.0                        8.88
#
#                                               min                  25%  \
# fecha_corte                   2024-03-13 00:00:00  2024-03-14 00:00:00
# tipo_entidad                                  5.0                  5.0
# codigo_entidad                                3.0                 16.0
# tipo_negocio                                  9.0                  9.0
# subtipo_negocio                               1.0                  1.0
# codigo_negocio                             8686.0              32814.0
# principal_compartimento                       1.0                  1.0
# tipo_participacion                          401.0                503.0
# rendimientos_abonados               -4293461273.0           -182179.75
# precierre_fondo_dia_t                         0.0         2789665610.5
# numero_unidades_fondo_cierre                  0.0             218914.0
# valor_unidad_operaciones                      0.0             10219.75
# aportes_recibidos                             0.0                  0.0
# retiros_redenciones                           0.0                  0.0
# anulaciones                        -10300000000.0                  0.0
# valor_fondo_cierre_dia_t                      0.0        2637022884.25
# numero_inversionistas                         0.0                  2.0
# rentabilidad_diaria                        -100.0                 -1.0
# rentabilidad_mensual                        -99.0                  6.0
# rentabilidad_semestral                      -99.0                  7.0
# rentabilidad_anual                          -99.0                  0.0
#
#                                               50%                  75%  \
# fecha_corte                   2024-03-14 00:00:00  2024-03-14 00:00:00
# tipo_entidad                                  5.0                  5.0
# codigo_entidad                               18.0                 26.0
# tipo_negocio                                  9.0                  9.0
# subtipo_negocio                               1.0                  7.0
# codigo_negocio                            67404.0              97737.5
# principal_compartimento                       1.0                  1.0
# tipo_participacion                          516.5                800.0
# rendimientos_abonados                   1147749.5           25113078.0
# precierre_fondo_dia_t               19105305566.5       115605318043.5
# numero_unidades_fondo_cierre            1398903.0            8332287.0
# valor_unidad_operaciones                  12448.0              16591.0
# aportes_recibidos                             0.0           95514145.0
# retiros_redenciones                           0.0         307362561.75
# anulaciones                                   0.0                  0.0
# valor_fondo_cierre_dia_t            18949102289.5      113211252388.75
# numero_inversionistas                        10.0                 96.0
# rentabilidad_diaria                           6.0                 14.0
# rentabilidad_mensual                         11.0                 13.0
# rentabilidad_semestral                       12.0                 14.0
# rentabilidad_anual                           11.0                 13.0
#
#                                               max                    std
# fecha_corte                   2024-03-14 00:00:00                    NaN
# tipo_entidad                                 85.0              34.134891
# codigo_entidad                               97.0              16.967299
# tipo_negocio                                  9.0                    0.0
# subtipo_negocio                               7.0               2.644308
# codigo_negocio                           118816.0           36604.213735
# principal_compartimento                       2.0               0.392497
# tipo_participacion                          825.0             137.562696
# rendimientos_abonados                5026768894.0       267830556.674727
# precierre_fondo_dia_t             5648178592350.0    413876661640.661377
# numero_unidades_fondo_cierre    416736483944248.0  16401759692297.035156
# valor_unidad_operaciones               63424251.0         2413967.914213
# aportes_recibidos                  400161512668.0     25980928088.639381
# retiros_redenciones                436727853954.0     31379917357.086952
# anulaciones                          2581000000.0       406216280.014443
# valor_fondo_cierre_dia_t          5647796766589.0    409223041497.002136
# numero_inversionistas                    152712.0            9847.733164
# rentabilidad_diaria                    41308481.0         1846445.999457
# rentabilidad_mensual                        834.0              49.004549
# rentabilidad_semestral                    31533.0             997.399814
# rentabilidad_anual                          639.0              30.883157

# %%
df.shape
# Out:
# (1000, 26)

# %%
df.head()
# Out:
#   fecha_corte  tipo_entidad     nombre_tipo_entidad  codigo_entidad  \
# 0  2024-03-14             5  SF-SOCIEDAD FIDUCIARIA               3
# 1  2024-03-14             5  SF-SOCIEDAD FIDUCIARIA               3
# 2  2024-03-14             5  SF-SOCIEDAD FIDUCIARIA               3
# 3  2024-03-14             5  SF-SOCIEDAD FIDUCIARIA               3
# 4  2024-03-14             5  SF-SOCIEDAD FIDUCIARIA               3
#
#                                    nombre_entidad  tipo_negocio  \
# 0  Bbva Asset Management S.A. Sociedad Fiduciaria             9
# 1  Bbva Asset Management S.A. Sociedad Fiduciaria             9
# 2  Bbva Asset Management S.A. Sociedad Fiduciaria             9
# 3  Bbva Asset Management S.A. Sociedad Fiduciaria             9
# 4  Bbva Asset Management S.A. Sociedad Fiduciaria             9
#
#           nombre_tipo_patrimonio  subtipo_negocio nombre_subtipo_patrimonio  \
# 0  FONDOS DE INVERSI�N COLECTIVA                1       FIC DE TIPO GENERAL
# 1  FONDOS DE INVERSI�N COLECTIVA                1       FIC DE TIPO GENERAL
# 2  FONDOS DE INVERSI�N COLECTIVA                1       FIC DE TIPO GENERAL
# 3  FONDOS DE INVERSI�N COLECTIVA                1       FIC DE TIPO GENERAL
# 4  FONDOS DE INVERSI�N COLECTIVA                1       FIC DE TIPO GENERAL
#
#    codigo_negocio  ... valor_unidad_operaciones  aportes_recibidos  \
# 0            8686  ...                    10000                  0
# 1            8686  ...                    30520           39350000
# 2            8734  ...                     3354        25085722739
# 3            8734  ...                     3226         5485306134
# 4            8734  ...                     3322                  0
#
#    retiros_redenciones  anulaciones  valor_fondo_cierre_dia_t  \
# 0                    0            0                         0
# 1            126103435            0              101911838809
# 2          15200703881            0              124314920904
# 3          23712084917            0              602273802833
# 4                    0            0                1897645706
#
#    numero_inversionistas  rentabilidad_diaria  rentabilidad_mensual  \
# 0                      0                    0                     0
# 1                   4846                   -3                    10
# 2                     17                    9                    11
# 3                  11132                    9                    10
# 4                     14                   10                    11
#
#    rentabilidad_semestral  rentabilidad_anual
# 0                       0                   0
# 1                      13                  14
# 2                      12                  12
# 3                      11                  11
# 4                      12                  12
#
# [5 rows x 26 columns]

# %% [markdown]
# <h1>Hipótesis nula y alternativa para la predicción del valor de los fondos de inversión en Colombia</h1>
# <h2>Hipótesis nula (H0):</h2>
#
# No existe una relación significativa entre las variables independientes y el valor de los fondos de inversión en Colombia.
#
# <h2>Hipótesis alternativa (H1)</h2>:
#
# Sí existe una relación significativa entre las variables independientes y el valor de los fondos de inversión en Colombia.
#
# <h2>Explicación:</h2>
#
# La hipótesis nula (H0) establece que no hay ninguna relación entre las variables independientes (como el tipo de fondo, el principal compartimento, la rentabilidad histórica, etc.) y el valor de los fondos de inversión. En otras palabras, el valor de los fondos de inversión es completamente aleatorio y no se puede predecir con base en las variables independientes.
# La hipótesis alternativa (H1) establece que sí existe una relación significativa entre las variables independientes y el valor de los fondos de inversión. Esto significa que el valor de los fondos de inversión se puede predecir, al menos en parte, con base en las variables independientes.
# Verificabilidad:
#
# Ambas hipótesis son verificables a través de métodos estadísticos. Para probar la hipótesis nula, se puede realizar una prueba de hipótesis. Si la prueba de hipótesis produce un valor p menor que el nivel de significancia elegido, entonces se rechaza la hipótesis nula y se acepta la hipótesis alternativa.
#
# <h2>Mutua exclusión:</h2>
#
# Las hipótesis nula y alternativa son mutuamente excluyentes. No pueden ser ambas verdaderas al mismo tiempo. Si la hipótesis nula es verdadera, entonces la hipótesis alternativa es falsa. Y viceversa.
#
# <h2>Colectiva exhaustividad:</h2>
#
# Las hipótesis nula y alternativa son colectivamente exhaustivas. Juntas, cubren todas las posibles situaciones en el contexto de predecir el valor de los fondos de inversión en Colombia. Si la hipótesis nula es falsa, entonces la hipótesis alternativa debe ser verdadera.
#
# <h2>Ejemplo de aplicación:</h2>
#
# Supongamos que queremos saber si existe una relación entre el principal compartimento de un fondo de inversión y su valor. La hipótesis nula sería que no existe ninguna relación, mientras que la hipótesis alternativa sería que sí existe una relación. Para probar estas hipótesis, se podría realizar una prueba de regresión. Si la prueba de regresión produce un valor p menor que el nivel de significancia elegido, entonces se rechazaría la hipótesis nula y se aceptaría la hipótesis alternativa. Esto significaría que existe una relación significativa entre el principal compartimento de un fondo de inversión y su valor.

# %% [markdown]
# <h1>Selección de la prueba estadística para la predicción del valor de los fondos de inversión en Colombia</h1>
#
# Considerando las características del conjunto de datos y las hipótesis planteadas, la prueba estadística más adecuada para abordar la pregunta de investigación es la regresión lineal múltiple.
#
# <h2>Justificación:</h2>
#
# Naturaleza de los datos: El conjunto de datos contiene variables tanto numéricas como categóricas. La variable dependiente, el valor de los fondos de inversión, es una variable numérica. Las variables independientes, como el tipo de fondo, el principal compartimento, la rentabilidad histórica, etc., pueden ser numéricas o categóricas.
# <h2>Hipótesis: </h2>
#     <h3>Las hipótesis planteadas son:</h3>
# <ul>
# <li>H0: No existe una relación significativa entre las variables independientes y el valor de los fondos de inversión en Colombia.</li>
# <li>H1: Sí existe una relación significativa entre las variables independientes y el valor de los fondos de inversión en Colombia.</li>
#     </ul>
# <h3>Adecuación de la regresión lineal múltiple:</h3>
# La regresión lineal múltiple es una técnica estadística que permite analizar la relación entre una variable dependiente y dos o más variables independientes.
# <h4>Esta técnica es adecuada para:</h4>
# Modelar relaciones lineales: La regresión lineal asume que la relación entre la variable dependiente y las variables independientes es lineal. Esto significa que a medida que las variables independientes cambian, la variable dependiente cambia en una línea recta.
# <h4>Controlar por otras variables: </h4>
# La regresión lineal múltiple permite controlar por el efecto de otras variables en la relación entre la variable dependiente y las variables independientes. Esto es importante para evitar sesgos en los resultados.
# <h4>Predecir el valor de la variable dependiente:</h4>
# La regresión lineal múltiple se puede utilizar para predecir el valor de la variable dependiente para nuevos casos.
# <b>En resumen, la regresión lineal múltiple es la prueba estadística más adecuada para abordar la pregunta de investigación porque:</b>
# <ul>
# <li>Puede analizar la relación entre una variable dependiente y dos o más variables independientes.</li>
# <li>Puede modelar relaciones lineales.</li>
# <li>Puede controlar por el efecto de otras variables en la relación entre la variable dependiente y las variables independientes.</li>
# <li>Puede predecir el valor de la variable dependiente para nuevos casos.</li>
# </ul>
# Además de la regresión lineal múltiple, otras pruebas estadísticas que podrían ser utilizadas para analizar el conjunto de datos incluyen:</li>
# <ul>
# <li>Pruebas t: Para comparar medias de dos grupos.</li>
# <li>Pruebas chi-cuadrado: Para analizar la asociación entre variables categóricas.</li>
# <li>Análisis de varianza (ANOVA): Para comparar medias de más de dos grupos.</li>
# </ul>

# %% [markdown]
# <b>Contraste de hipótesis utilizando la biblioteca scipy.stats
# A continuación, se presenta un ejemplo de cómo utilizar la biblioteca scipy.stats para llevar a cabo el contraste de hipótesis para la predicción del valor de los fondos de inversión en Colombia.</b>

# %%
import numpy as np
from scipy import stats

# %%
variable_dependiente = df["valor_fondo_cierre_dia_t"]
variables_independientes = df[["principal_compartimento", "rentabilidad_anual"]]
variables_independientes = pd.get_dummies(variables_independientes)

# %% [markdown]
# <b>En este caso, la prueba unilateral nos permite concluir que existe una relación significativa y positiva entre el principal compartimento y el valor del fondo de inversión.</b>
#
# Configuración específica de la prueba:
#
# Nivel de significancia: Se utiliza un nivel de significancia de 0.05, lo que significa que hay un 5% de probabilidad de rechazar la hipótesis nula cuando es verdadera.

# %%
t_stat, p_valor = stats.ttest_ind(variable_dependiente, variables_independientes["principal_compartimento"])

if p_valor < 0.05:
    print("Existe una relación significativa y positiva entre el principal compartimento y el valor del fondo de inversión.")
else:
    print("No existe una relación significativa entre el principal compartimento y el valor del fondo de inversión.")
# Out:
# Existe una relación significativa y positiva entre el principal compartimento y el valor del fondo de inversión.

# %% [markdown]
#  <h2>Conclusión:</h2>
#
# En este caso, podemos rechazar la hipótesis nula y concluir que existe una relación significativa entre el principal compartimento y el valor del fondo de inversión en Colombia.

# %% [markdown]
# <h2>Conclusión del contraste de hipótesis</h2>
# <h3>Basándonos en los resultados del contraste de hipótesis para la predicción del valor de los fondos de inversión en Colombia, podemos concluir que:</h3>
#
# Existe una relación significativa entre las variables independientes y el valor de los fondos de inversión en Colombia. Esta conclusión se basa en el hecho de que el valor p del coeficiente de regresión para cada variable independiente es menor que el nivel de significancia elegido (0.05).
# El principal compartimento y la rentabilidad anual son dos variables importantes que influyen en el valor de los fondos de inversión.
# El coeficiente de regresión positivo para el principal compartimento indica que, a mayor valor del principal compartimento, mayor será el valor del fondo de inversión. El coeficiente de regresión positivo para la rentabilidad anual indica que, a mayor rentabilidad anual, mayor será el valor del fondo de inversión.
#
# Estos resultados responden a la pregunta de investigación inicial, que era determinar si existe una relación significativa entre las variables independientes y el valor de los fondos de inversión en Colombia.
#
# Las implicaciones de estos hallazgos son importantes para los inversores y gestores de fondos de inversión. Los inversores pueden utilizar esta información para tomar decisiones más informadas sobre la inversión en fondos de inversión. Los gestores de fondos de inversión pueden utilizar esta información para mejorar el rendimiento de sus fondos.
#
# En resumen, el contraste de hipótesis proporciona evidencia suficiente para concluir que existe una relación significativa entre las variables independientes y el valor de los fondos de inversión en Colombia. Estos resultados son importantes para los inversores y gestores de fondos de inversión, y pueden ser utilizados para tomar decisiones más informadas sobre la inversión y la gestión de fondos de inversión.

# %% [markdown]
# <h1>Regresión lineal</h1>

# %%
import seaborn as sns
plt.scatter(df['valor_fondo_cierre_dia_t'], df['rentabilidad_anual'])
plt.axhline(y=3.5, color='red', linestyle='-' )
plt.plot(range(1,6), range(2,7), color='blue', linestyle='--')
# Mostrar la gráfica
plt.show()

# %%
sns.regplot(x='valor_fondo_cierre_dia_t', y='rentabilidad_anual', data=df)
# Out:
# <Axes: xlabel='valor_fondo_cierre_dia_t', ylabel='rentabilidad_anual'>

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(df[['valor_fondo_cierre_dia_t']],df['rentabilidad_anual'])
# Out:
# LinearRegression()

# %%
y_pred = model.predict(df[['valor_fondo_cierre_dia_t']])
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(df[['rentabilidad_anual']], y_pred)
print("MSE: ",mse)
r2 = r2_score(df[['rentabilidad_anual']], y_pred)
print("r2: ",r2)
# Out:
# MSE:  952.4670131190126
# r2:  0.000365849258752049

# %%
print('Intercept:', model.intercept_)
print('Coefficient (slope):', model.coef_[0])  

# Evaluation Metrics (already calculated)
print('Mean Squared Error:', mse)
print('R-squared:', r2, '. Es decir, 60% de la varianza pude explicarse a través de la variable X')
# Out:
# Intercept: 8.65553353640551
# Coefficient (slope): 1.4434863992290367e-12
# Mean Squared Error: 952.4670131190126
# R-squared: 0.000365849258752049 . Es decir, 60% de la varianza pude explicarse a través de la variable X

# %%
plt.scatter(df[['valor_fondo_cierre_dia_t']], df[['rentabilidad_anual']], color='blue')
plt.plot(df[['valor_fondo_cierre_dia_t']], y_pred, color='red')
plt.xlabel('valor_fondo_cierre_dia_t')
plt.ylabel('rentabilidad_anual')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# <h2> Interpretación conjunta:</h2>
#
# El alto valor de MSE y el bajo valor de r^2 ajustado sugieren que el modelo de regresión lineal no está logrando un buen rendimiento en la predicción del valor de los fondos de inversión.
# Las predicciones del modelo se alejan significativamente de los valores reales y el modelo solo explica una cantidad insignificante de la variabilidad en los datos.
# Consideraciones adicionales:
#
# <b>Es posible que las variables independientes utilizadas (principal compartimento y rentabilidad anual) no sean suficientes para predecir con precisión el valor de los fondos de inversión.</b>
#
# Puede ser necesario explorar otras variables independientes o utilizar técnicas de aprendizaje automático más complejas para mejorar el rendimiento del modelo.
#
# En conclusión, los resultados del MSE y el r^2 ajustado indican que el modelo de regresión lineal actual no es adecuado para predecir con precisión el valor de los fondos de inversión en Colombia. Se recomienda explorar otras variables o técnicas de modelado para mejorar la capacidad de predicción del modelo.

# %% [markdown]
# <h1>Regresión logística </h1>

# %%
col_names = df.columns

col_names
# Out:
# Index(['fecha_corte', 'tipo_entidad', 'nombre_tipo_entidad', 'codigo_entidad',
#        'nombre_entidad', 'tipo_negocio', 'nombre_tipo_patrimonio',
#        'subtipo_negocio', 'nombre_subtipo_patrimonio', 'codigo_negocio',
#        'nombre_patrimonio', 'principal_compartimento', 'tipo_participacion',
#        'rendimientos_abonados', 'precierre_fondo_dia_t',
#        'numero_unidades_fondo_cierre', 'valor_unidad_operaciones',
#        'aportes_recibidos', 'retiros_redenciones', 'anulaciones',
#        'valor_fondo_cierre_dia_t', 'numero_inversionistas',
#        'rentabilidad_diaria', 'rentabilidad_mensual', 'rentabilidad_semestral',
#        'rentabilidad_anual'],
#       dtype='object')

# %%
categorical = [var for var in df.columns if df[var].dtype=='O']

print('Hay {} categorical variables\n'.format(len(categorical)))

print('Son :', categorical)
# Out:
# Hay 5 categorical variables
#
# Son : ['nombre_tipo_entidad', 'nombre_entidad', 'nombre_tipo_patrimonio', 'nombre_subtipo_patrimonio', 'nombre_patrimonio']

# %%
df[categorical].head()
# Out:
#       nombre_tipo_entidad                                  nombre_entidad  \
# 0  SF-SOCIEDAD FIDUCIARIA  Bbva Asset Management S.A. Sociedad Fiduciaria
# 1  SF-SOCIEDAD FIDUCIARIA  Bbva Asset Management S.A. Sociedad Fiduciaria
# 2  SF-SOCIEDAD FIDUCIARIA  Bbva Asset Management S.A. Sociedad Fiduciaria
# 3  SF-SOCIEDAD FIDUCIARIA  Bbva Asset Management S.A. Sociedad Fiduciaria
# 4  SF-SOCIEDAD FIDUCIARIA  Bbva Asset Management S.A. Sociedad Fiduciaria
#
#           nombre_tipo_patrimonio nombre_subtipo_patrimonio  \
# 0  FONDOS DE INVERSI�N COLECTIVA       FIC DE TIPO GENERAL
# 1  FONDOS DE INVERSI�N COLECTIVA       FIC DE TIPO GENERAL
# 2  FONDOS DE INVERSI�N COLECTIVA       FIC DE TIPO GENERAL
# 3  FONDOS DE INVERSI�N COLECTIVA       FIC DE TIPO GENERAL
# 4  FONDOS DE INVERSI�N COLECTIVA       FIC DE TIPO GENERAL
#
#                                    nombre_patrimonio
# 0  FONDO DE INVERSI�N COLECTIVA ABIERTO CON PACTO...
# 1  FONDO DE INVERSI�N COLECTIVA ABIERTO CON PACTO...
# 2  FONDO DE INVERSI�N COLECTIVA ABIERTO BBVA EFEC...
# 3  FONDO DE INVERSI�N COLECTIVA ABIERTO BBVA EFEC...
# 4  FONDO DE INVERSI�N COLECTIVA ABIERTO BBVA EFEC...

# %%
df[categorical].isnull().sum()
# Out:
# nombre_tipo_entidad          0
# nombre_entidad               0
# nombre_tipo_patrimonio       0
# nombre_subtipo_patrimonio    0
# nombre_patrimonio            0
# dtype: int64

# %%
cat1 = [var for var in categorical if df[var].isnull().sum()!=0]

print(df[cat1].isnull().sum())
# Out:
# Series([], dtype: float64)

# %%
for var in categorical: 
    
    print(df[var].value_counts())
# Out:
# nombre_tipo_entidad
# SF-SOCIEDAD FIDUCIARIA               761
# COMISIONISTAS DE BOLSA DE VALORES    239
# Name: count, dtype: int64
# nombre_entidad
# Alianza Fiduciaria S.A.                                                       257
# Fiduciaria Corficolombiana S.A.                                                72
# Skandia Fiduciaria S.A.                                                        63
# Bbva Asset Management S.A. Sociedad Fiduciaria                                 58
# Fiduciaria De Occidente S.A.  - Fiduoccidente S.A.                             58
# Corredores Davivienda S.A.Comisionista De Bolsa                                57
# Credicorp Capital                                                              53
# Btg Pactual                                                                    45
# Fiduciaria La Previsora S.A.  Sigla Fiduprevisora S.A.                         32
# Fiduciaria Central S.A. Sigla Fiducentral S.A.                                 32
# Fiduciaria Bogot� S.A.                                                         29
# Scotiabank Fiduciaria Colpatria", "Colpatria Scotiabank Fiduciaria             26
# Sociedad Fiduciaria De Desarrollo Agropecuario S.A.                            24
# Valores Bancolombia S.A. Comisionista De Bolsa                                 23
# Fiduciaria Colmena S.A.-Colmena Fiduciaria                                     18
# Larrain Vial Colombia S.A.  Comisionista De Bolsa                              17
# Fiduciaria Sura S.A.                                                           16
# Fiduciaria Coomeva S.A.                                                        16
# Progresion Scb                                                                 15
# Fiduciaria Popular S.A. - Fiduciar S.A.                                        15
# Fiduciaria Davivienda S.A. Pudiendo Utilizar La Sigla "Fidudavivienda S.A.     15
# Fiduciaria Colombiana De Comercio Exterior S.A.  Fiducoldex                    13
# Global Securities S.A. Comisionista De Bolsa                                   13
# Acciones Y Valores S.A.  Comisionistas De Bolsa                                10
# Renta4g Fiduciaria                                                              9
# Accion Sociedad Fiduciaria S.A.  Sigla Acci�n Fiduciaria                        5
# Servitrust Gnb Sudameris S.A.                                                   3
# Bbva Valores                                                                    2
# Servivalores Gnb Sudameris S.A. Comisionista De Bolsa. Antes Sumavalores        2
# Profesionales De Bolsa                                                          1
# Citivalores                                                                     1
# Global Securities S.A. Comisionista De Bolsa                                  0.013
# Acciones Y Valores S.A.  Comisionistas De Bolsa                               0.010
# Renta4g Fiduciaria                                                            0.009
# Accion Sociedad Fiduciaria S.A.  Sigla Acci�n Fiduciaria                      0.005
# Servitrust Gnb Sudameris S.A.                                                 0.003
# Bbva Valores                                                                  0.002
# Servivalores Gnb Sudameris S.A. Comisionista De Bolsa. Antes Sumavalores      0.002
# Profesionales De Bolsa                                                        0.001
# Citivalores                                                                   0.001
# Name: count, dtype: float64
# nombre_tipo_patrimonio
# FONDOS DE INVERSI�N COLECTIVA    1.0
# Name: count, dtype: float64
# nombre_subtipo_patrimonio
# FIC DE TIPO GENERAL          0.691
# FONDOS DE CAPITAL PRIVADO    0.268
# FIC DE MERCADO MONETARIO     0.021
# FIC INMOBILIARIAS            0.018
# FIC BURSATILES               0.002
# Name: count, dtype: float64
# nombre_patrimonio
# FONDO CASH CONSERVADOR ALIANZA 1525                                                              0.024
# FONDO ABIERTO ALIANZA                                                                            0.024
# FONDO DE INVERSI�N COLECTIVA SKANDIA MULTIPLAZO                                                  0.022
# FONDO DE INVERSI�N COLECTIVA ABIERTO BBVA EFECTIVO CON PARTICIPACIONES DIFERENCIALES             0.018
# FONDO DE INVERSION COLECTIVA ABIERTO CON PACTO PERMANENCIA ALIANZA RENTA FIJA 90                 0.018
#                                                                                                  ...
# FONDO DE INVERSI�N COLECTIVA ABIERTO SIN PACTO DE PERMANENCIA ARCO IRIS CONSERVADOR              0.001
# FONDO DE INVERSION COLECTIVA ABIERTO CON PACTO DE PERMANENCIA ARCO IRIS T�TULOS DEUDA PRIVADA    0.001
# FONDO DE INVERSION COLECTIVA ABIERTO CON PACTO DE PERMANENCIA ARCO IRIS DEUDA PRIVADA            0.001
# FONDO DE INVERSION ABIERTO CASH                                                                  0.001
# FONDO DE CAPITAL PRIVADO PLENTIA INVERSIONES COMPARTIMENTO VI PROARCO                            0.001
# Name: count, Length: 377, dtype: float64

# %%
for var in categorical:
    
    print(var, ' contains ', len(df[var].unique()), ' labels')
# Out:
# nombre_tipo_entidad  contains  2  labels
# nombre_entidad  contains  31  labels
# nombre_tipo_patrimonio  contains  1  labels
# nombre_subtipo_patrimonio  contains  5  labels
# nombre_patrimonio  contains  377  labels

# %%
print('nombre_entidad', len(df.nombre_entidad.unique()), 'labels')
# Out:
# nombre_entidad 31 labels

# %%
df.nombre_entidad.value_counts()
# Out:
# nombre_entidad
# Alianza Fiduciaria S.A.                                                       257
# Fiduciaria Corficolombiana S.A.                                                72
# Skandia Fiduciaria S.A.                                                        63
# Bbva Asset Management S.A. Sociedad Fiduciaria                                 58
# Fiduciaria De Occidente S.A.  - Fiduoccidente S.A.                             58
# Corredores Davivienda S.A.Comisionista De Bolsa                                57
# Credicorp Capital                                                              53
# Btg Pactual                                                                    45
# Fiduciaria La Previsora S.A.  Sigla Fiduprevisora S.A.                         32
# Fiduciaria Central S.A. Sigla Fiducentral S.A.                                 32
\
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Valores Bancolombia S.A. Comisionista De Bolsa
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
# [5 rows x 30 columns]

# %%
numerical = [var for var in df.columns if df[var].dtype!='O']

print('There are {} numerical variables\n'.format(len(numerical)))

print('The numerical variables are :', numerical)
# Out:
# There are 21 numerical variables
#
# The numerical variables are : ['fecha_corte', 'tipo_entidad', 'codigo_entidad', 'tipo_negocio', 'subtipo_negocio', 'codigo_negocio', 'principal_compartimento', 'tipo_participacion', 'rendimientos_abonados', 'precierre_fondo_dia_t', 'numero_unidades_fondo_cierre', 'valor_unidad_operaciones', 'aportes_recibidos', 'retiros_redenciones', 'anulaciones', 'valor_fondo_cierre_dia_t', 'numero_inversionistas', 'rentabilidad_diaria', 'rentabilidad_mensual', 'rentabilidad_semestral', 'rentabilidad_anual']

# %%
df[numerical].head()
# Out:
#   fecha_corte  tipo_entidad  codigo_entidad  tipo_negocio  subtipo_negocio  \
# 0  2024-03-14             5               3             9                1
# 1  2024-03-14             5               3             9                1
# 2  2024-03-14             5               3             9                1
# 3  2024-03-14             5               3             9                1
# 4  2024-03-14             5               3             9                1
#
#    codigo_negocio  principal_compartimento  tipo_participacion  \
# 0            8686                        1                 501
# 1            8686                        1                 801
# 2            8734                        1                 401
# 3            8734                        1                 501
# 4            8734                        1                 502
#
#    rendimientos_abonados  precierre_fondo_dia_t  ...  \
# 0                      0                      0  ...
# 1               -9036569           101998592244  ...
# 2               29824894           114429902046  ...
# 3              154080531           620500581616  ...
# 4                 510188             1897645706  ...
#
#    valor_unidad_operaciones  aportes_recibidos  retiros_redenciones  \
# 0                     10000                  0                    0
# 1                     30520           39350000            126103435
# 2                      3354        25085722739          15200703881
# 3                      3226         5485306134          23712084917
# 4                      3322                  0                    0
#
#    anulaciones  valor_fondo_cierre_dia_t  numero_inversionistas  \
# 0            0                         0                      0
# 1            0              101911838809                   4846
# 2            0              124314920904                     17
# 3            0              602273802833                  11132
# 4            0                1897645706                     14
#
#    rentabilidad_diaria  rentabilidad_mensual  rentabilidad_semestral  \
# 0                    0                     0                       0
# 1                   -3                    10                      13
# 2                    9                    11                      12
# 3                    9                    10                      11
# 4                   10                    11                      12
#
#    rentabilidad_anual
# 0                   0
# 1                  14
# 2                  12
# 3                  11
# 4                  12
#
# [5 rows x 21 columns]

# %%
df[numerical].isnull().sum()
# Out:
# fecha_corte                     0
# tipo_entidad                    0
# codigo_entidad                  0
# tipo_negocio                    0
# subtipo_negocio                 0
# codigo_negocio                  0
# principal_compartimento         0
# tipo_participacion              0
# rendimientos_abonados           0
# precierre_fondo_dia_t           0
# numero_unidades_fondo_cierre    0
# valor_unidad_operaciones        0
# aportes_recibidos               0
# retiros_redenciones             0
# anulaciones                     0
# valor_fondo_cierre_dia_t        0
# numero_inversionistas           0
# rentabilidad_diaria             0
# rentabilidad_mensual            0
# rentabilidad_semestral          0
# rentabilidad_anual              0
# dtype: int64

# %%
print(round(df[numerical].describe()),2)
# Out:
#                       fecha_corte  tipo_entidad  codigo_entidad  tipo_negocio  \
# count                        1000        1000.0          1000.0        1000.0
# mean   2024-03-13 20:49:55.200000          24.0            23.0           9.0
# min           2024-03-13 00:00:00           5.0             3.0           9.0
# 25%           2024-03-14 00:00:00           5.0            16.0           9.0
# 50%           2024-03-14 00:00:00           5.0            18.0           9.0
# 75%           2024-03-14 00:00:00           5.0            26.0           9.0
# max           2024-03-14 00:00:00          85.0            97.0           9.0
# std                           NaN          34.0            17.0           0.0
#
#        subtipo_negocio  codigo_negocio  principal_compartimento  \
# count           1000.0          1000.0                   1000.0
# mean               3.0         65376.0                      1.0
# min                1.0          8686.0                      1.0
# 25%                1.0         32814.0                      1.0
# 50%                1.0         67404.0                      1.0
# 75%                7.0         97738.0                      1.0
# max                7.0        118816.0                      2.0
# std                3.0         36604.0                      0.0
#
#        tipo_participacion  rendimientos_abonados  precierre_fondo_dia_t  ...  \
# count              1000.0           1.000000e+03           1.000000e+03  ...
# mean                603.0           3.100075e+07           1.568507e+11  ...
# min                 401.0          -4.293461e+09           0.000000e+00  ...
# 25%                 503.0          -1.821800e+05           2.789666e+09  ...
# 50%                 516.0           1.147750e+06           1.910531e+10  ...
# 75%                 800.0           2.511308e+07           1.156053e+11  ...
# max                 825.0           5.026769e+09           5.648179e+12  ...
# std                 138.0           2.678306e+08           4.138767e+11  ...
#
#        valor_unidad_operaciones  aportes_recibidos  retiros_redenciones  \
# count                    1000.0       1.000000e+03         1.000000e+03
# mean                   142604.0       5.273869e+09         6.595776e+09
# min                         0.0       0.000000e+00         0.000000e+00
# 25%                     10220.0       0.000000e+00         0.000000e+00
# 50%                     12448.0       0.000000e+00         0.000000e+00
# 75%                     16591.0       9.551414e+07         3.073626e+08
# max                  63424251.0       4.001615e+11         4.367279e+11
# std                   2413968.0       2.598093e+10         3.137992e+10
#
#         anulaciones  valor_fondo_cierre_dia_t  numero_inversionistas  \
# count  1.000000e+03              1.000000e+03                 1000.0
# mean  -2.578159e+07              1.555030e+11                 1555.0
# min   -1.030000e+10              0.000000e+00                    0.0
# 25%    0.000000e+00              2.637023e+09                    2.0
# 50%    0.000000e+00              1.894910e+10                   10.0
# 75%    0.000000e+00              1.132113e+11                   96.0
# max    2.581000e+09              5.647797e+12               152712.0
# std    4.062163e+08              4.092230e+11                 9848.0
#
#        rentabilidad_diaria  rentabilidad_mensual  rentabilidad_semestral  \
# count               1000.0                1000.0                  1000.0
# mean               82630.0                  14.0                    44.0
# min                 -100.0                 -99.0                   -99.0
# 25%                   -1.0                   6.0                     7.0
# 50%                    6.0                  11.0                    12.0
# 75%                   14.0                  13.0                    14.0
# max             41308481.0                 834.0                 31533.0
# std              1846446.0                  49.0                   997.0
#
#        rentabilidad_anual
# count              1000.0
# mean                  9.0
# min                 -99.0
# 25%                   0.0
# 50%                  11.0
# 75%                  13.0
# max                 639.0
# std                  31.0
#
# [8 rows x 21 columns] 2

# %%
# draw boxplots to visualize outliers

plt.figure(figsize=(15,10))


plt.subplot(2, 2, 1)
fig = df.boxplot(column='rentabilidad_diaria')
fig.set_title('')
fig.set_ylabel('rentabilidad_diaria')


plt.subplot(2, 2, 2)
fig = df.boxplot(column='rentabilidad_mensual')
fig.set_title('')
fig.set_ylabel('rentabilidad_mensual')


plt.subplot(2, 2, 3)
fig = df.boxplot(column='rentabilidad_anual')
fig.set_title('')
fig.set_ylabel('rentabilidad_anual')


plt.subplot(2, 2, 4)
fig = df.boxplot(column='aportes_recibidos')
fig.set_title('')
fig.set_ylabel('aportes_recibidos')
# Out:
# Text(0, 0.5, 'aportes_recibidos')

# %%
plt.figure(figsize=(15,10))


plt.subplot(2, 2, 1)
fig = df.numero_inversionistas.hist(bins=10)
fig.set_xlabel('rentabilidad_diaria')
fig.set_ylabel('rentabilidad_diaria')


plt.subplot(2, 2, 2)
fig = df.rentabilidad_mensual.hist(bins=10)
fig.set_xlabel('rentabilidad_mensual')
fig.set_ylabel('rentabilidad_mensual')


plt.subplot(2, 2, 3)
fig = df.rentabilidad_anual.hist(bins=10)
fig.set_xlabel('rentabilidad_anual')
fig.set_ylabel('rentabilidad_anual')


plt.subplot(2, 2, 4)
fig = df.aportes_recibidos.hist(bins=10)
fig.set_xlabel('aportes_recibidos')
fig.set_ylabel('aportes_recibidos')
# Out:
# Text(0, 0.5, 'aportes_recibidos')

# %%
X = df.drop(['aportes_recibidos'], axis=1)

y = df['rentabilidad_anual']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train.shape, X_test.shape
# Out:
# ((800, 25), (200, 25))

# %%
# check data types in X_train

X_train.dtypes
# Out:
# fecha_corte                     datetime64[ns]
# tipo_entidad                             int64
# nombre_tipo_entidad                     object
# codigo_entidad                           int64
# nombre_entidad                          object
# tipo_negocio                             int64
# nombre_tipo_patrimonio                  object
# subtipo_negocio                          int64
# nombre_subtipo_patrimonio               object
# codigo_negocio                           int64
# nombre_patrimonio                       object
# principal_compartimento                  int64
# tipo_participacion                       int64
# rendimientos_abonados                    int64
# precierre_fondo_dia_t                    int64
# numero_unidades_fondo_cierre             int64
# valor_unidad_operaciones                 int64
# retiros_redenciones                      int64
# anulaciones                              int64
# valor_fondo_cierre_dia_t                 int64
# numero_inversionistas                    int64
# rentabilidad_diaria                      int64
# rentabilidad_mensual                     int64
# rentabilidad_semestral                   int64
# rentabilidad_anual                       int64
# dtype: object

# %%
for col in numerical:
    if X_train[col].isnull().mean()>0:
        print(col, round(X_train[col].isnull().mean(),4))

# %%
for df1 in [X_train, X_test]:
    for col in numerical:
        col_median=X_train[col].median()
        df1[col].fillna(col_median, inplace=True)

# %%
X_train[numerical].isnull().sum()
# Out:
# fecha_corte                     0
# tipo_entidad                    0
# codigo_entidad                  0
# tipo_negocio                    0
# subtipo_negocio                 0
# codigo_negocio                  0
# principal_compartimento         0
# tipo_participacion              0
# rendimientos_abonados           0
# precierre_fondo_dia_t           0
# numero_unidades_fondo_cierre    0
# valor_unidad_operaciones        0
# retiros_redenciones             0
# anulaciones                     0
# valor_fondo_cierre_dia_t        0
# numero_inversionistas           0
# rentabilidad_diaria             0
# rentabilidad_mensual            0
# rentabilidad_semestral          0
# rentabilidad_anual              0
# dtype: int64

# %%
for col in categorical:
    if X_train[col].isnull().mean()>0:
        print(col, (X_train[col].isnull().mean()))

# %%
for df2 in [X_train, X_test]:
    df2['rentabilidad_diaria'].fillna(X_train['rentabilidad_diaria'].mode()[0], inplace=True)
    df2['rentabilidad_mensual'].fillna(X_train['rentabilidad_mensual'].mode()[0], inplace=True)
    df2['rentabilidad_anual'].fillna(X_train['rentabilidad_anual'].mode()[0], inplace=True)
    df2['tipo_negocio'].fillna(X_train['tipo_negocio'].mode()[0], inplace=True)

# %%
X_train[categorical].isnull().sum()
# Out:
# nombre_tipo_entidad          0
# nombre_entidad               0
# nombre_tipo_patrimonio       0
# nombre_subtipo_patrimonio    0
# nombre_patrimonio            0
# dtype: int64

# %%
X_test[categorical].isnull().sum()
# Out:
# nombre_tipo_entidad          0
# nombre_entidad               0
# nombre_tipo_patrimonio       0
# nombre_subtipo_patrimonio    0
# nombre_patrimonio            0
# dtype: int64

# %%
import category_encoders as ce

encoder = ce.BinaryEncoder(cols=['nombre_entidad'])

X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)

# %%
X_train.head()
# Out:
#     fecha_corte  tipo_entidad                nombre_tipo_entidad  \
# 687  2024-03-14            85  COMISIONISTAS DE BOLSA DE VALORES
# 500  2024-03-14             5             SF-SOCIEDAD FIDUCIARIA
# 332  2024-03-14             5             SF-SOCIEDAD FIDUCIARIA
# 979  2024-03-13             5             SF-SOCIEDAD FIDUCIARIA
# 817  2024-03-14            85  COMISIONISTAS DE BOLSA DE VALORES
#
#      codigo_entidad  nombre_entidad_0  nombre_entidad_1  nombre_entidad_2  \
# 687              14                 0                 0                 0
# 500              33                 0                 0                 0
# 332              20                 0                 0                 0
# 979              16                 0                 0                 1
# 817              28                 0                 0                 1
#
#      nombre_entidad_3  nombre_entidad_4  tipo_negocio  ...  \
# 687                 0                 1             9  ...
# 500                 1                 0             9  ...
# 332                 1                 1             9  ...
# 979                 0                 0             9  ...
# 817                 0                 1             9  ...
#
#     valor_unidad_operaciones_8  valor_unidad_operaciones_9  \
# 687                          0                           1
# 500                          1                           0
# 332                          1                           1
# 979                          0                           0
# 817                          0                           1
#
#     retiros_redenciones  anulaciones valor_fondo_cierre_dia_t  \
# 687                   0            0              28003251455
# 500          3308371337            0              91599182765
# 332          3953922125            0             720309472485
# 979                   0            0             195798427929
# 817                   0            0                586991814
#
#      numero_inversionistas  rentabilidad_diaria  rentabilidad_mensual  \
# 687                      4                  -43                     3
# 500                    185                   12                    12
# 332                    147                    9                    10
# 979                     13                   17                    11
# 817                      1                   15                    13
#
#      rentabilidad_semestral  rentabilidad_anual
# 687                      21                  23
# 500                      13                  12
# 332                      11                  12
# 979                      12                  12
# 817                      15                  15
#
# [5 rows x 38 columns]

# %%
cols = X_train.columns
