# %% [markdown]
# <b> Predicción del Rendimiento de Fondos de Inversión en Colombia </b>
#
# En el dinámico escenario financiero de Colombia, la gestión efectiva de fondos de inversión colectiva (FIC) es esencial para asegurar la rentabilidad de las inversiones y atraer a potenciales inversionistas. La corporación, consciente de la importancia de anticipar con precisión el rendimiento de los FIC, se embarca en un proyecto estratégico que busca aprovechar herramientas avanzadas de cálculo integral para mejorar significativamente la predicción de rendimientos.
#
# El proyecto se enfrenta a la problemática inherente a las dificultades en la predicción exacta del rendimiento de los FIC. Esta problemática impacta directamente la capacidad de la corporación para tomar decisiones informadas, optimizar la gestión de carteras y mantener una posición competitiva en el mercado financiero colombiano.
#
# Con el objetivo de superar estos desafíos, el proyecto propone la aplicación de técnicas específicas de cálculo integral, tales como antiderivadas, integral definida e integral indefinida. Estas técnicas se emplearán en el análisis de datos históricos de rentabilidades diarias, permitiendo una comprensión más profunda de la evolución del rendimiento de los FIC a lo largo del tiempo.
#
# Además, se llevará a cabo una exhaustiva revisión bibliográfica, explorando fuentes académicas, informes de organismos financieros y estudios de investigación relacionados. Esta revisión proporcionará un marco teórico sólido y enriquecerá la comprensión de enfoques exitosos implementados en situaciones problemáticas similares en el ámbito de las finanzas y la gestión de inversiones.
#
# A través de esta iniciativa, la corporación busca no solo mejorar su capacidad para prever el rendimiento de los FIC, sino también fortalecer su posición en el competitivo mercado financiero colombiano, atraer inversionistas y optimizar estratégicamente sus decisiones de inversión. Este proyecto representa un paso significativo hacia la innovación y la eficiencia en la gestión financiera, destacando el compromiso de la corporación con la excelencia y la adaptación a las complejidades del entorno financiero actual.

# %%
import requests
import pandas as pd

# %%
def query_data_paginated(url, params={}, headers={}, page_size=100000):
    """
    Queries data from the specified URL using paginated requests with offset and limit parameters.

    Args:
        url (str): The URL of the API endpoint.
        params (dict, optional): Additional query parameters to include. Defaults to {}.
        headers (dict, optional): HTTP headers to include in the request. Defaults to {}.
        page_size (int, optional): The number of records to retrieve per page. Defaults to 1000.

    Returns:
        list: A list of all retrieved data records.
    """

    all_data = []
    offset = 0

    while True:
        limit = page_size
        params["$offset"] = offset
        params["$limit"] = limit

        # Make the request and handle potential errors
        try:
            response = requests.get(url, headers=headers, params=params)
            response.raise_for_status()  # Raise an exception if request fails
        except requests.exceptions.RequestException as e:
            print(f"Error making request: {e}")
            break

        data = response.json()  # Assuming data is in JSON format, adjust if necessary

        if not data:  # Check for empty data to avoid infinite loop
            break

        all_data.extend(data)
        offset += limit

    return all_data

url = "https://www.datos.gov.co/resource/qhpu-8ixx.json" # Replace with your actual URL
headers = {"Accept": "application/json"}  # Adjust headers if needed

data = query_data_paginated(url, headers=headers)
df = pd.DataFrame(data)

print(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1970508 entries, 0 to 1970507
# Data columns (total 26 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   fecha_corte                   object
#  1   tipo_entidad                  object
#  2   nombre_tipo_entidad           object
#  3   codigo_entidad                object
#  4   nombre_entidad                object
#  5   tipo_negocio                  object
#  6   nombre_tipo_patrimonio        object
#  7   subtipo_negocio               object
#  8   nombre_subtipo_patrimonio     object
#  9   codigo_negocio                object
#  10  nombre_patrimonio             object
#  11  principal_compartimento       object
#  12  tipo_participacion            object
#  13  rendimientos_abonados         object
#  14  precierre_fondo_dia_t         object
#  15  numero_unidades_fondo_cierre  object
#  16  valor_unidad_operaciones      object
#  17  aportes_recibidos             object
# ...

# %% [markdown]
# ## Corrección de campos

# %%
# Diccionario con los tipos de datos
tipos_datos = {
"fecha_corte":"datetime64[ns]",
"tipo_entidad":"int64",         
"nombre_tipo_entidad":"str",
"codigo_entidad":"int64",	   
"nombre_entidad":"str",       
"tipo_negocio":"int64",         
"nombre_tipo_patrimonio":"str",
"subtipo_negocio":"int64",      
"nombre_subtipo_patrimonio":"str",
"codigo_negocio":"int64",      
"nombre_patrimonio":"str",  
"principal_compartimento":"float",
"tipo_participacion":"float",   
"rendimientos_abonados":"float",
"precierre_fondo_dia_t":"float",
"numero_unidades_fondo_cierre":"float", 
"valor_unidad_operaciones":"float",
"aportes_recibidos":"float",
"retiros_redenciones":"float",  
"anulaciones":"float",      
"valor_fondo_cierre_dia_t":"float",
"numero_inversionistas":"float", 
"rentabilidad_diaria":"float", 
"rentabilidad_mensual":"float", 
"rentabilidad_semestral":"float",
"rentabilidad_anual":"float"
}

# Cambia el tipo de dato de las columnas
for campo, tipo in tipos_datos.items():
    df[campo] = df[campo].astype(tipo)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1970508 entries, 0 to 1970507
# Data columns (total 26 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   fecha_corte                   datetime64[ns]
#  1   tipo_entidad                  int64
#  2   nombre_tipo_entidad           object
#  3   codigo_entidad                int64
#  4   nombre_entidad                object
#  5   tipo_negocio                  int64
#  6   nombre_tipo_patrimonio        object
#  7   subtipo_negocio               int64
#  8   nombre_subtipo_patrimonio     object
#  9   codigo_negocio                int64
#  10  nombre_patrimonio             object
#  11  principal_compartimento       float64
#  12  tipo_participacion            float64
#  13  rendimientos_abonados         float64
#  14  precierre_fondo_dia_t         float64
#  15  numero_unidades_fondo_cierre  float64
#  16  valor_unidad_operaciones      float64
# ...

# %% [markdown]
# # Limpieza inicial

# %%
df.isnull().sum()
# Out:
# fecha_corte                     0
# tipo_entidad                    0
# nombre_tipo_entidad             0
# codigo_entidad                  0
# nombre_entidad                  0
# tipo_negocio                    0
# nombre_tipo_patrimonio          0
# subtipo_negocio                 0
# nombre_subtipo_patrimonio       0
# codigo_negocio                  0
# nombre_patrimonio               0
# principal_compartimento         0
# tipo_participacion              0
# rendimientos_abonados           0
# precierre_fondo_dia_t           0
# numero_unidades_fondo_cierre    0
# valor_unidad_operaciones        0
# aportes_recibidos               0
# retiros_redenciones             0
# anulaciones                     0
# valor_fondo_cierre_dia_t        0
# numero_inversionistas           0
# rentabilidad_diaria             0
# rentabilidad_mensual            0
# rentabilidad_semestral          0
# rentabilidad_anual              0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                                   count                           mean  \
# fecha_corte                     1970508  2020-08-02 01:20:13.124737792
# tipo_entidad                  1970508.0                       31.66706
# codigo_entidad                1970508.0                      26.646881
# tipo_negocio                  1970508.0                            9.0
# subtipo_negocio               1970508.0                       2.809751
# codigo_negocio                1970508.0                   55179.056353
# principal_compartimento       1970508.0                       1.202382
# tipo_participacion            1970508.0                     637.897656
# rendimientos_abonados         1970508.0                25205668.401203
# precierre_fondo_dia_t         1970508.0            158140761938.474121
# numero_unidades_fondo_cierre  1970508.0            631766354621.399292
# valor_unidad_operaciones      1970508.0                  109548.580458
# ...

# %%
##Revisar correlación con el tipo de entidad
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df["rentabilidad_semestral"])
plt.xlabel("Rentabilidad diaria")
plt.ylabel("Frecuencia")
plt.show()

# %%
variables = ["principal_compartimento", "rentabilidad_mensual", "numero_inversionistas"]
for variable in variables:
    plt.hist(df[variable])
    plt.title(variable)
    plt.show()

# %%
for variable in variables:
    sns.boxplot(x=variable, data=df)
    plt.title(variable)
    plt.show()

# %%
for variable in variables:
    sns.displot(df[variable], kind="kde")
    plt.title(variable)
    plt.show()
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
for variable1 in variables:
    for variable2 in variables:
        if variable1 != variable2:
            plt.scatter(df[variable1], df[variable2])
            plt.xlabel(variable1)
            plt.ylabel(variable2)
            plt.show()

# %%
plt.matshow(df.corr())
plt.title("Matriz de correlación")
plt.xticks(range(df.shape[1]), df.columns, fontsize=10)
plt.yticks(range(df.shape[1]), df.columns, fontsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 plt.matshow(df.corr())
#       2 plt.title("Matriz de correlación")
#       3 plt.xticks(range(df.shape[1]), df.columns, fontsize=10)
#
# File D:\anaconda\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File D:\anaconda\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...

# %%
df['nombre_tipo_entidad'].unique()
# Out:
# array(['SF-SOCIEDAD FIDUCIARIA', 'COMISIONISTAS DE BOLSA DE VALORES',
#        'SOCIEDADES ADMINISTRADORAS DE INVERSI�N'], dtype=object)
